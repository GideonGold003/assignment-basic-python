# %%
name = input("Please enter your name: ")
age = input("Please Enter your age: ")
print(f"Hello {name}, you are {age} years old")

# %%
Length = float(input("Pleae enter the length of the rectangle: "))
Width = float(input("Please enter the width of the rectangle: "))
Area = Length * Width
print(f"The length entered is: {Length}, the Width is: {Width}, and the Area = {Area}")

# %%
days = float(input("Please enter the number of days: ")

# %%
Test_1 = float(input("Please the score of First test: "))
Test_2 = float(input("Please the score of Second test: "))
Test_3 = float(input("Please the score of Third test: "))

AverageScore = (Test_1 + Test_2 + Test_3) / 3
print(f"The Average of {Test_1} , {Test_2} , {Test_3} is = {AverageScore}")

# %% [markdown]
# # Qtn 5

# %%
radius = float(input("Please enter the Radius: "))
pie = 3.14159
Area = pie * radius**2
circumference = 2 * pie * radius
print(f"The Area of the circle is {Area} \nThe Circumference of the Circle is = {circumference}")

# %% [markdown]
# # Qtn 6

# %%
first = float(input("Enter your First Number: "))
second = float(input("Enter your Second Number: "))

summation = first + second
difference = first - second
product = first * second
remainder = first // second
quotient = first % second
power = first ** second

print(f"sum = {summation} \nDifference = {difference} \nProduct = {product} \nRemainder = {remainder} \nQuotient = {quotient} \nPower = {power}")

# %% [markdown]
# # Qtn 7

# %%
temperature = float(input("Please Enter the Temperature: "))
Fahrenheit = (temperature * 9/5) + 32
print(f"The Temperature is {temperature} oC, converted = {Fahrenheit} oF")

# %% [markdown]
# # Qtn 8

# %%
weight = float(input("Please Enter the Weight: "))
height = float(input("Please Enter the Height: "))
BMI = weight / (height) ** 2

print(f"Weight = {weight} \nHeight = {height} \nBMI = {BMI}")

# %% [markdown]
# # Qtn 9

# %%
Sentence = input("Please type in a sentence: ")
remove = Sentence.replace(" ","") 
print(f"The count for your Sentence is: {len(remove)}")
# Out:
# Please type in a sentence:  1 2 3 4 5
# The count for your Sentence is: 5

# %% [markdown]
# # Qtn 10

# %%
SideLength = float(input("Please Enter the side of The Cube"))

volume = SideLength ** 3
Surface_Area = SideLength * (SideLength)**2
print(f"volume is:  {volume}")
print(f"Surface Aree is: {Surface_Area}")
# Out:
# Please Enter the side of The Cube 12
# volume is:  1728.0
# Surface Aree is: 1728.0

# %% [markdown]
# # Qtn 11

# %%
FirstName = input("Please Enter your First Name: ")
LastName = input("Please Enter your Last Name: ")
Initials = FirstName[0] + "." + LastName[0]
print(f"Your Name is: {FirstName} {LastName}")
print(f"Your Initials are: {Initials}")
# Out:
# Please Enter your First Name:  Gideon
# Please Enter your Last Name:  oladele
# Your Name is: Gideon oladele
# Your Initials are: G.O

# %% [markdown]
# # Qtn 12

# %%
principal = float(input("Please Enter the Principal Amount: "))
Rate = float(input("Please Enter the Interest Rate: "))
Time = float(input("Please Enter the Time Period (In Years): "))

SimpleInterest = (principal * Rate * Time) / 100

print(f"Principal = {principal}")
print(f"Rate = {Rate}")
print(f"Time = {Time}")
print(f"Simple Interest = {SimpleInterest}")
# Out:
# Please Enter the Principal Amount:  2000
# Please Enter the Interest Rate:  1
# Please Enter the Time Period (In Years):  2
# Principal = 2000.0
# Rate = 1.0
# Time = 2.0
# Simple Interest = 40.0

# %% [markdown]
# # Qtn 13

# %%
Height = float(input("Please Enter the Height of the Traingle: "))
Base = float(input("Please Enter the Base of the Traingle: "))

Area = (Base * Height) / 2

print(f"The Area of the Triangle is: {Area}")
# Out:
# Please Enter the Height of the Traingle:  12
# Please Enter the Base of the Traingle:  6
# The Area of the Triangle is: 36.0

# %% [markdown]
# # Qtn 14

# %%
Height = float(input("Please Enter the Height of the Wall: "))
Width = float(input("Please Enter the Width of the Wall: "))

WallArea = Height * Width

LitreNeeded = WallArea / 10

print(f"The amount of paint needed for the Wall Area is: {LitreNeeded}")
# Out:
# Please Enter the Height of the Wall:  12
# Please Enter the Width of the Wall:  14
# The amount of paint needed for the Wall Area is: 16.8

# %% [markdown]
# # Qtn 15

# %% [markdown]
# # Qtn 16

# %% [markdown]
# # Qtn 17
